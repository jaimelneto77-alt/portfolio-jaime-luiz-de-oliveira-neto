# %%
# 🚀 Desafios Desenvolvidos

### 1. 🎨 O Criador de Emojis (Pixels RGB)
Neste desafio, o foco é a manipulação de cores e coordenadas. Através de matrizes bidimensionais, representamos imagens digitais onde cada elemento corresponde a um pixel com valores RGB, permitindo a construção de ícones e emojis via código.

🔗 [Acessar Desafio 1 no Google Colab](https://colab.research.google.com/drive/1PgQrXmxqjUYXh66qyFAwlIFMQ6nV53PB#scrollTo=Z4UMtqZ13cYK&line=41&uniqifier=1)

### 2. 🎵 Matrizes Musicais (Transposição)
Este módulo explora a relação entre música e matemática. O algoritmo lida com estruturas de dados que representam notas musicais, realizando a transposição de tons através da manipulação de índices em matrizes, garantindo a harmonia da composição após a alteração.

🔗 [Acessar Desafio 2 no Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=39wGbWat5Bf2&line=4&uniqifier=1)

### 3. 🛠️ O Integrador (Criação Livre)
O desafio final consolida os conhecimentos adquiridos. Trata-se de uma implementação livre onde as técnicas de entrada de dados, processamento lógico e saída estruturada são integradas para resolver um problema complexo definido pelo desenvolvedor.
